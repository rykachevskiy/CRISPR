# %%
import numpy as np
import crispr_assembler as ca
import matplotlib.pyplot as plt
import editdistance as ed
import os
import pickle


# %load_ext autoreload
# %autoreload 2

# %%
db_c = pickle.load(open("../../data/db_as_clusters", 'rb'))

# %%
gr = ca.graph_from_arrays(db_c)[0]

# %%
ca.plot_gr(gr[:100, :100], log = 1, s = 14)
